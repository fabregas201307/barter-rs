# %% [markdown]
# ## use pre-compiled binary without re-compile

# %%
# %%time
# !/usr/local/bin/bond_event_signals_backtest /workspace/data/bond_marks_template.csv /workspace/data/bond_signals_template.csv
# Out:
# Using provided paths:
#   Marks: /workspace/data/bond_marks_template.csv
#   Signals: /workspace/data/bond_signals_template.csv
#
#  BOND EVENT BACKTEST SUMMARY
# ┌──────────────────────────┬──────────┐
# │ Metric                   │ Value    │
# ├──────────────────────────┼──────────┤
# │ Total Return             │ -0.0217% │
# ├──────────────────────────┼──────────┤
# │ Annualized Return (CAGR) │ -0.0216% │
# ├──────────────────────────┼──────────┤
# │ Max Drawdown             │ -0.1124% │
# ├──────────────────────────┼──────────┤
# │ Annualized Volatility    │ 0.0828%  │
# ├──────────────────────────┼──────────┤
# │ Sharpe Ratio (Ann.)      │ -0.2621  │
# ├──────────────────────────┼──────────┤
# │ Trading Days             │ 366      │
# └──────────────────────────┴──────────┘
#
# First 5 points:
#   2025-01-01 nav=1.000000 dd=0.000000
#   2025-01-02 nav=0.999977 dd=-0.000022
#   2025-01-03 nav=0.999950 dd=-0.000049
#   2025-01-04 nav=0.999930 dd=-0.000069
#   2025-01-05 nav=0.999927 dd=-0.000072
#
# Last 5 points:
#   2025-12-28 nav=0.999782 dd=-0.000217
#   2025-12-29 nav=0.999782 dd=-0.000217
#   2025-12-30 nav=0.999782 dd=-0.000217
#   2025-12-31 nav=0.999782 dd=-0.000217
#   2026-01-01 nav=0.999782 dd=-0.000217
# CPU times: user 11.8 ms, sys: 12.9 ms, total: 24.7 ms
# Wall time: 436 ms

# %% [markdown]
# ## re-compile binary without on the fly

# %%
# %%time
# !cargo run --release -p barter --example bond_event_signals_backtest -- /workspace/data/bond_marks_template.csv /workspace/data/bond_signals_template.csv
# Out:
# info: syncing channel updates for 'stable-aarch64-unknown-linux-gnu'
# info: latest update on 2026-01-22, rust version 1.93.0 (254b59607 2026-01-19)
# info: downloading component 'cargo'
# info: downloading component 'clippy'
# info: downloading component 'rust-std'
# info: downloading component 'rustc'
# info: downloading component 'rustfmt'
# info: installing component 'cargo'
# info: installing component 'clippy'
# info: installing component 'rust-std'
# info: installing component 'rustc'
# info: installing component 'rustfmt'
#     Updating crates.io index
#   Downloaded atomic-waker v1.1.2
#   Downloaded block-buffer v0.10.4ytes: 636.0KiB
#   Downloaded is-terminal v0.4.17bytes: 588.1KiB
#   Downloaded futures-io v0.3.31 bytes: 3.1MiB
#   Downloaded form_urlencoded v1.2.2es: 3.1MiB
#   Downloaded pin-utils v0.1.0ng bytes: 3.1MiB
#   Downloaded cfg-if v1.0.4ining bytes: 3.6MiB
#   Downloaded itoa v1.0.17aining bytes: 4.3MiB
#   Downloaded cpufeatures v0.2.17bytes: 4.2MiB
#   Downloaded proc-macro-crate v3.4.0s: 4.1MiB
#   Downloaded bytecheck_derive v0.6.12: 4.2MiB
#   Downloaded anstyle v1.0.13ing bytes: 4.0MiB
#   Downloaded generic-array v0.14.7tes: 3.9MiB
#   Downloaded plotters-svg v0.3.7bytes: 3.9MiB
#   Downloaded lazy_static v1.5.0 bytes: 6.5MiB
#   Downloaded convert_case v0.6.0bytes: 6.7MiB
#   Downloaded lru-slab v0.1.2ing bytes: 6.5MiB
#   Downloaded hyper-rustls v0.27.7ytes: 9.1MiB
#   Downloaded spin_sleep v1.3.3g bytes: 8.9MiB
#   Downloaded futures-task v0.3.31ytes: 8.8MiB
#   Downloaded http-body-util v0.1.3tes: 8.6MiB
#   Downloaded half v2.7.1maining bytes: 8.5MiB
#   Downloaded subtle v2.6.1ining bytes: 8.3MiB
#   Downloaded tracing-log v0.2.0 bytes: 8.1MiB
#   Downloaded icu_provider v2.1.1bytes: 8.0MiB
#   Downloaded version_check v0.9.5ytes: 9.2MiB
#   Downloaded want v0.3.1maining bytes: 9.2MiB
#   Downloaded ptr_meta v0.1.4ing bytes: 9.2MiB
#   Downloaded convert_case v0.10.0ytes: 10.2MiB
#   Downloaded hex v0.4.3emaining bytes: 10.0MiB
#   Downloaded yoke v0.8.1maining bytes: 10.2MiB
#   Downloaded tracing-attributes v0.1.319.9MiB
#   Downloaded zerovec-derive v0.11.2es: 9.9MiB
#   Downloaded criterion v0.5.1ng bytes: 9.6MiB
#   Downloaded zeroize v1.8.2ning bytes: 9.5MiB
#   Downloaded wyz v0.5.1emaining bytes: 9.2MiB
#   Downloaded toml_parser v1.0.6+spec-1.1.0MiB
#   Downloaded zerofrom v0.1.6ing bytes: 8.7MiB
#   Downloaded webpki-roots v0.26.11tes: 8.6MiB
#   Downloaded zmij v1.0.14aining bytes: 8.9MiB
#   Downloaded zerofrom-derive v0.1.6es: 8.7MiB
#   Downloaded tracing-subscriber v0.3.228.6MiB
#   Downloaded tokio-tungstenite v0.26.2 8.4MiB
#   Downloaded prettytable-rs v0.10.0es: 8.2MiB
#   Downloaded rand_core v0.9.5ng bytes: 8.1MiB
#   Downloaded pin-project-internal v1.1.109MiB
#   Downloaded tap v1.0.1emaining bytes: 8.2MiB
#   Downloaded ptr_meta_derive v0.1.4es: 8.0MiB
#   Downloaded tinyvec_macros v0.1.1tes: 7.8MiB
#   Downloaded hyper-util v0.1.19 bytes: 7.7MiB
#   Downloaded unicode-xid v0.2.6 bytes: 7.5MiB
#   Downloaded zerocopy v0.8.33ng bytes: 7.3MiB
#   Downloaded zerocopy-derive v0.8.33s: 7.2MiB
#   Downloaded zerotrie v0.2.3ing bytes: 6.6MiB
#   Downloaded socket2 v0.6.1ning bytes: 5.9MiB
#   Downloaded url v2.5.8emaining bytes: 5.3MiB
#   Downloaded rand v0.8.5maining bytes: 4.8MiB
#   Downloaded rand v0.9.2maining bytes: 4.5MiB
#   Downloaded zerovec v0.11.5ing bytes: 4.1MiB
#   Downloaded serde_json v1.0.149bytes: 3.8MiB
#   Downloaded tower-http v0.6.8g bytes: 3.5MiB
#   Downloaded winnow v0.7.14ning bytes: 3.3MiB
#   Downloaded rayon v1.10.0ining bytes: 3.1MiB
#   Downloaded syn v1.0.109aining bytes: 2.9MiB
#   Downloaded webpki-roots v1.0.5bytes: 2.8MiB
#   Downloaded quinn-proto v0.11.13ytes: 2.6MiB
#   Downloaded regex v1.12.2ining bytes: 2.5MiB
#   Downloaded rust_decimal v1.40.0ytes: 2.3MiB
#   Downloaded syn v2.0.114aining bytes: 2.2MiB
#   Downloaded reqwest v0.12.28ng bytes: 2.1MiB
#   Downloaded rustls v0.23.36ing bytes: 2.0MiB
#   Downloaded regex-syntax v0.8.8bytes: 1.9MiB
#   Downloaded rkyv v0.7.46aining bytes: 1.8MiB
#   Downloaded plotters v0.3.7ing bytes: 1.7MiB
#   Downloaded tracing v0.1.44ing bytes: 1.7MiB
#   Downloaded mio v1.1.1xtracting tracing ...
#   Downloaded quinn v0.11.9ining bytes: 1.6MiB
#   Downloaded memchr v2.7.6ining bytes: 1.5MiB
#   Downloaded serde v1.0.228ning bytes: 1.5MiB
#   Downloaded rustls-webpki v0.103.8es: 1.4MiB
#   Downloaded serde_derive v1.0.228tes: 1.3MiB
#   Downloaded rayon-core v1.12.1 bytes: 1.3MiB
#   Downloaded prost-derive v0.12.6ytes: 1.2MiB
#   Downloaded regex-automata v0.4.13es: 1.2MiB
#   Downloaded proc-macro2 v1.0.105regex-automata ...
#   Downloaded pin-project v1.1.10bytes: 1.1MiB
#   Downloaded parking_lot v0.12.5bytes: 1.1MiB
#   Downloaded log v0.4.29maining bytes: 1.0MiB
#   Downloaded tokio-stream v0.1.18ytes: 1011.1KiB
#   Downloaded tinyvec v1.10.0ing bytes: 992.3KiB
#   Downloaded smallvec v1.15.1ng bytes: 944.4KiB
#   Downloaded sharded-slab v0.1.7bytes: 912.4KiB
#   Downloaded serde_qs v0.13.0ng bytes: 880.4KiB
#   Downloaded serde_core v1.0.228bytes: 848.5KiB
#   Downloaded ryu v1.0.22maining bytes: 816.4KiB
#   Downloaded rand_core v0.6.4ng bytes: 780.3KiB
#   Downloaded quote v1.0.43ining bytes: 744.3KiB
#   Downloaded tokio v1.49.0ining bytes: 712.3KiB
#   Downloaded parking_lot_core v0.9.12o ...
#   Downloaded oorandom v11.1.5ng bytes: 664.4KiB
#   Downloaded once_cell v1.21.3g bytes: 635.4KiB
#   Downloaded num-traits v0.2.19 bytes: 619.4KiB
#   Downloaded lock_api v0.4.14ng bytes: 603.4KiB
#   Downloaded untrusted v0.9.0ng bytes: 587.4KiB
#   Downloaded tokio-rustls v0.26.4ytes: 571.4KiB
#   Downloaded tinytemplate v1.2.1bytes: 555.4KiB
#   Downloaded tinystr v0.8.2ning bytes: 539.4KiB
#   Downloaded thiserror-impl v1.0.69es: 519.4KiB
#   Downloaded thiserror v2.0.17g bytes: 503.4KiB
#   Downloaded thiserror v1.0.69g bytes: 487.4KiB
#   Downloaded term v0.7.0maining bytes: 471.4KiB
#   Downloaded smol_str v0.3.5ing bytes: 455.4KiB
#   Downloaded slab v0.4.11aining bytes: 439.4KiB
#   Downloaded simdutf8 v0.1.5ing bytes: 419.4KiB
#   Downloaded shlex v1.3.0aining bytes: 403.4KiB
#   Downloaded seahash v4.1.0ning bytes: 387.4KiB
#   Downloaded scopeguard v1.2.0g bytes: 371.4KiB
#   Downloaded rustls-pki-types v1.13.2: 355.4KiB
#   Downloaded rustc-hash v2.1.1g bytes: 339.4KiB
#   Downloaded quinn-udp v0.5.14g bytes: 319.4KiB
#   Downloaded prost v0.12.6ining bytes: 303.4KiB
#   Downloaded unicode-width v0.1.14tes: 287.4KiB
#   Downloaded thread_local v1.1.9bytes: 271.4KiB
#   Downloaded tokio-macros v2.6.0bytes: 255.4KiB
#   Downloaded thiserror-impl v2.0.17es: 239.4KiB
#   Downloaded sync_wrapper v1.0.2bytes: 219.4KiB
#   Downloaded signal-hook-registry v1.4.803.4KiB
#   Downloaded semver v1.0.27ning bytes: 187.4KiB
#   Downloaded rand_chacha v0.9.0 bytes: 171.4KiB
#   Downloaded csv v1.4.0emaining bytes: 155.4KiB
#   Downloaded same-file v1.0.6ing csv ...
#   Downloaded rand_chacha v0.3.1 bytes: 119.4KiB
#   Downloaded vecmap-rs v0.2.4ng bytes: 103.4KiB
#   Downloaded unicode-segmentation v1.12.0.4KiB
#   Downloaded synstructure v0.13.2ytes: 71.4KiB
#   Downloaded rkyv_derive v0.7.46bytes: 55.4KiB
#   Downloaded http v1.4.0maining bytes: 39.4KiB
#   Downloaded typenum v1.19.0ing bytes: 23.4KiB
#   Downloaded ring v0.17.14ining bytes: 7.4KiB
#   Downloaded tracing-serde v0.2.0ring ...
#   Downloaded tower-layer v0.3.3
#   Downloaded libc v0.2.180
#   Downloaded writeable v0.6.2ing libc ...
#   Downloaded utf8_iter v1.0.4
#   Downloaded try-lock v0.2.5
#   Downloaded pin-project-lite v0.2.16
#   Downloaded nu-ansi-term v0.50.3
#   Downloaded httparse v1.10.1
#   Downloaded tracing-core v0.1.36
#   Downloaded tokio-util v0.7.18
#   Downloaded icu_properties_data v2.1.2
#   Downloaded hyper v1.8.1
#   Downloaded hashbrown v0.16.1
#   Downloaded futures-util v0.3.31
#   Downloaded clap_builder v4.4.18
#   Downloaded chrono v0.4.43
#   Downloaded bitvec v1.0.1
#   Downloaded aho-corasick v1.1.4
#   Downloaded yoke-derive v0.8.1
#   Downloaded walkdir v2.5.0
#   Downloaded tungstenite v0.26.2
#   Downloaded itertools v0.14.0
#   Downloaded iri-string v0.7.10
#   Downloaded idna v1.1.0
#   Downloaded unicode-ident v1.0.22
#   Downloaded crossbeam-deque v0.8.6
#   Downloaded tower v0.5.3
#   Downloaded stable_deref_trait v1.2.1
#   Downloaded sha1 v0.10.6
#   Downloaded itertools v0.12.1
#   Downloaded uuid v1.19.0
#   Downloaded itertools v0.10.5
#   Downloaded crossbeam-utils v0.8.21
#   Downloaded hashbrown v0.12.3
#   Downloaded getrandom v0.3.4
#   Downloaded derive_more-impl v2.1.1
#   Downloaded anes v0.1.6
#   Downloaded plotters-backend v0.3.7
#   Downloaded icu_properties v2.1.2
#   Downloaded icu_collections v2.1.1
#   Downloaded futures-channel v0.3.31
#   Downloaded cc v1.2.52
#   Downloaded toml_edit v0.23.10+spec-1.0.0
#   Downloaded toml_datetime v0.7.5+spec-1.1.0
#   Downloaded serde_urlencoded v0.7.1
#   Downloaded rust_decimal_macros v1.40.0
#   Downloaded indexmap v2.13.0
#   Downloaded errno v0.3.14
#   Downloaded dirs-next v2.0.0
#   Downloaded derive_more v2.1.1
#   Downloaded clap v4.4.18
#   Downloaded utf-8 v0.7.6
#   Downloaded tower-service v0.3.3
#   Downloaded ppv-lite86 v0.2.21
#   Downloaded icu_normalizer v2.1.1
#   Downloaded encode_unicode v1.0.0
#   Downloaded borsh v1.6.0
#   Downloaded base64 v0.22.1
#   Downloaded icu_normalizer_data v2.1.1
#   Downloaded icu_locale_core v2.1.1
#   Downloaded bytes v1.11.0
#   Downloaded litemap v0.8.1
#   Downloaded displaydoc v0.2.5
#   Downloaded rustc_version v0.4.1
#   Downloaded rend v0.4.2
#   Downloaded hmac v0.12.1
#   Downloaded futures v0.3.31
#   Downloaded data-encoding v2.10.0
#   Downloaded futures-executor v0.3.31
#   Downloaded funty v2.0.0
#   Downloaded csv-core v0.1.13
#   Downloaded anyhow v1.0.100
#   Downloaded radium v0.7.0
#   Downloaded iana-time-zone v0.1.64
#   Downloaded getrandom v0.2.17
#   Downloaded find-msvc-tools v0.1.7
#   Downloaded crossbeam-epoch v0.9.18
#   Downloaded ciborium v0.2.2
#   Downloaded ahash v0.7.8
#   Downloaded autocfg v1.5.0
#   Downloaded async-trait v0.1.89
#   Downloaded clap_lex v0.6.0
#   Downloaded futures-macro v0.3.31
#   Downloaded digest v0.10.7
#   Downloaded criterion-plot v0.5.0
#   Downloaded borsh-derive v1.6.0
#   Downloaded bitflags v2.10.0
#   Downloaded percent-encoding v2.3.2
#   Downloaded ipnet v2.11.0
#   Downloaded either v1.15.0
#   Downloaded futures-core v0.3.31
#   Downloaded fnv v1.0.7
#   Downloaded arrayvec v0.7.6
#   Downloaded potential_utf v0.1.4
#   Downloaded matchers v0.2.0
#   Downloaded idna_adapter v1.2.1
#   Downloaded equivalent v1.0.2
#   Downloaded crypto-common v0.1.7
#   Downloaded ciborium-ll v0.2.2
#   Downloaded ciborium-io v0.2.2
#   Downloaded cast v0.3.0
#   Downloaded cfg_aliases v0.2.1
#   Downloaded http-body v1.0.1
#   Downloaded futures-sink v0.3.31
#   Downloaded dirs-sys-next v0.1.2
#   Downloaded bytecheck v0.6.12
#   Downloaded 246 crates (17.7MiB) in 1.34s (largest was `ring` at 1.4MiB)
#    Compiling proc-macro2 v1.0.105
#    Compiling unicode-ident v1.0.22
#    Compiling quote v1.0.43
#    Compiling libc v0.2.180
#    Compiling cfg-if v1.0.4
#    Compiling serde_core v1.0.228
#    Compiling pin-project-lite v0.2.16 ] 0/266: cfg-if, serde_core(build.rs…
#    Compiling itoa v1.0.17             ] 1/266: serde_core(build.rs), proc-…
#    Compiling memchr v2.7.6            ] 2/266: serde_core(build.rs), proc-…
#    Compiling stable_deref_trait v1.2.1] 3/266: serde_core(build.rs), proc-…
#    Compiling bytes v1.11.0            ] 4/266: serde_core(build.rs), proc-…
#    Compiling futures-core v0.3.31     ] 5/266: serde_core(build.rs), proc-…
#    Compiling serde v1.0.228           ] 6/266: futures-core, serde_core(bu…
#    Compiling smallvec v1.15.1         ] 7/266: serde_core(build.rs), proc-…
#    Compiling once_cell v1.21.3        ] 8/266: serde_core(build.rs), proc-…
#    Compiling futures-sink v0.3.31     ] 9/266: serde_core(build.rs), proc-…
#    Compiling shlex v1.3.0            ] 11/266: quote(build), serde_core(bu…
#    Compiling find-msvc-tools v0.1.7  ] 12/266: quote(build), serde_core(bu…
#    Compiling cc v1.2.52              ] 14/266: find-msvc-tools, proc-macro…
#    Compiling zerocopy v0.8.33        ] 18/266: find-msvc-tools, serde_core…
#    Compiling errno v0.3.14           ] 23/266: proc-macro2, serde_core, ze…
#    Compiling syn v2.0.114            ] 24/266: errno, serde_core, zerocopy…
#    Compiling signal-hook-registry v1.4.85/266: errno, serde_core, zerocopy…
#    Compiling socket2 v0.6.1          ] 26/266: errno, serde_core, signal-h…
#    Compiling mio v1.1.1              ] 27/266: errno, serde_core, signal-h…
#    Compiling ring v0.17.14           ] 28/266: serde_core, signal-hook-reg…
#    Compiling futures-channel v0.3.31 ] 29/266: ring(build.rs), signal-hook…
#    Compiling version_check v0.9.5    ] 30/266: ring(build.rs), futures-cha…
#    Compiling typenum v1.19.0         ] 31/266: ring(build.rs), futures-cha…
#    Compiling pin-utils v0.1.0        ] 32/266: ring(build.rs), typenum(bui…
#    Compiling zeroize v1.8.2          ] 33/266: ring(build.rs), typenum(bui…
#    Compiling litemap v0.8.1          ] 34/266: ring(build.rs), typenum(bui…
#    Compiling writeable v0.6.2        ] 36/266: ring(build.rs), typenum(bui…
#    Compiling rustls-pki-types v1.13.2] 37/266: ring(build.rs), typenum(bui…
#    Compiling generic-array v0.14.7   ] 38/266: ring(build.rs), typenum(bui…
#    Compiling http v1.4.0             ] 39/266: ring(build.rs), typenum(bui…
#    Compiling synstructure v0.13.2    ] 40/266: ring(build.rs), typenum(bui…
#    Compiling icu_properties_data v2.1.241/266: ring(build.rs), typenum(bui…
#    Compiling slab v0.4.11            ] 43/266: ring(build.rs), typenum(bui…
#    Compiling subtle v2.6.1           ] 44/266: ring(build.rs), icu_propert…
#    Compiling futures-io v0.3.31      ] 45/266: ring(build.rs), subtle, icu…
#    Compiling icu_normalizer_data v2.1.146/266: ring(build.rs), subtle, icu…
#    Compiling futures-task v0.3.31    ] 47/266: ring(build.rs), icu_propert…
#    Compiling zerofrom-derive v0.1.6  ] 48/266: ring(build.rs), futures-tas…
#    Compiling yoke-derive v0.8.1      ] 49/266: ring(build.rs), futures-tas…
#    Compiling zerovec-derive v0.11.2  ] 50/266: ring(build.rs), futures-tas…
#    Compiling displaydoc v0.2.5       ] 51/266: ring(build.rs), yoke-derive…
#    Compiling serde_derive v1.0.228   ] 52/266: ring(build.rs), displaydoc,…
#    Compiling tokio-macros v2.6.0     ] 53/266: ring(build.rs), displaydoc,…
#    Compiling zerocopy-derive v0.8.33 ] 54/266: tokio-macros, displaydoc, y…
#    Compiling futures-macro v0.3.31   ] 56/266: tokio-macros, ring(build), …
#    Compiling zerofrom v0.1.6         ] 57/266: tokio-macros, ring(build), …
#    Compiling yoke v0.8.1             ] 58/266: tokio-macros, ring(build), …
#    Compiling zerovec v0.11.5         ] 59/266: tokio-macros, ring(build), …
#    Compiling tokio v1.49.0           ] 60/266: ring(build), futures-macro,…
#    Compiling tinystr v0.8.2          ] 61/266: ring(build), futures-macro,…
#    Compiling icu_locale_core v2.1.1  ] 62/266: ring(build), futures-macro,…
#    Compiling potential_utf v0.1.4    ] 63/266: icu_locale_core, ring(build…
#    Compiling zerotrie v0.2.3         ] 65/266: ring(build), futures-macro,…
#    Compiling percent-encoding v2.3.2 ] 66/266: ring(build), futures-macro,…
#    Compiling icu_provider v2.1.1     ] 67/266: ring(build), futures-macro,…
#    Compiling icu_collections v2.1.1  ] 68/266: ring(build), futures-macro,…
#    Compiling getrandom v0.2.17       ] 73/266: ring(build), futures-macro,…
#    Compiling autocfg v1.5.0          ] 74/266: ring(build), futures-macro,…
#    Compiling httparse v1.10.1        ] 75/266: ring(build), futures-macro,…
#    Compiling untrusted v0.9.0        ] 76/266: ring(build), futures-macro,…
#    Compiling num-traits v0.2.19      ] 77/266: ring(build), futures-macro,…
#    Compiling futures-util v0.3.31    ] 78/266: ring(build), futures-macro,…
#    Compiling tracing-core v0.1.36    ] 84/266: futures-util, ring(build), …
#    Compiling getrandom v0.3.4        ] 85/266: futures-util, ring(build), …
#    Compiling rustls v0.23.36         ] 86/266: futures-util, ring(build), …
#    Compiling zmij v1.0.14            ] 87/266: futures-util, ring(build), …
#    Compiling icu_normalizer v2.1.1   ] 89/266: ring(build), getrandom(buil…
#    Compiling icu_properties v2.1.2   ] 90/266: ring(build), getrandom(buil…
#    Compiling http-body v1.0.1        ] 94/266: icu_properties, httparse, g…
#    Compiling unicode-segmentation v1.12.0/266: icu_properties, httparse, r…
#    Compiling serde_json v1.0.149     ] 97/266: icu_properties, httparse, r…
#    Compiling rustls-webpki v0.103.8  ] 99/266: icu_properties, serde_json(…
#    Compiling idna_adapter v1.2.1    ] 100/266: rustls-webpki, serde_json(b…
#    Compiling block-buffer v0.10.4   ] 104/266: rustls-webpki, serde_json(b…
#    Compiling crypto-common v0.1.7   ] 106/266: rustls-webpki, serde_json(b…
#    Compiling form_urlencoded v1.2.2 ] 107/266: rustls-webpki, serde_json(b…
#    Compiling tracing-attributes v0.1.3108/266: rustls-webpki, serde_json(b…
#    Compiling either v1.15.0         ] 109/266: rustls-webpki, serde_json(b…
#    Compiling thiserror v2.0.17      ] 111/266: rustls-webpki, tracing-attr…
#    Compiling tower-service v0.3.3   ] 112/266: rustls-webpki, tracing-attr…
#    Compiling try-lock v0.2.5        ] 113/266: rustls-webpki, tower-servic…
#    Compiling utf8_iter v1.0.4       ] 114/266: rustls-webpki, tracing-attr…
#    Compiling log v0.4.29            ] 115/266: rustls-webpki, tracing-attr…
#    Compiling idna v1.1.0            ] 116/266: rustls-webpki, tracing-attr…
#    Compiling want v0.3.1            ] 117/266: tracing-attributes, idna, r…
#    Compiling digest v0.10.7         ] 119/266: tracing-attributes, idna, r…
#    Compiling rand_core v0.9.5       ] 120/266: tracing-attributes, idna, r…
#    Compiling ppv-lite86 v0.2.21     ] 121/266: tracing-attributes, idna, r…
#    Compiling thiserror-impl v2.0.17 ] 122/266: tracing-attributes, idna, r…
#    Compiling webpki-roots v1.0.5    ] 124/266: thiserror(build), tracing-a…
#    Compiling ryu v1.0.22            ] 125/266: thiserror(build), webpki-ro…
#    Compiling atomic-waker v1.1.2    ] 126/266: webpki-roots, tracing-attri…
#    Compiling anyhow v1.0.100        ] 127/266: atomic-waker, tracing-attri…
#    Compiling hyper v1.8.1           ] 128/266: atomic-waker, tracing-attri…
#    Compiling rand_chacha v0.9.0     ] 129/266: hyper, tracing-attributes, …
#    Compiling tokio-rustls v0.26.4   ] 130/266: hyper, tracing-attributes, …
#    Compiling url v2.5.8             ] 131/266: hyper, tracing-attributes, …
#    Compiling convert_case v0.10.0   ] 133/266: anyhow(build), hyper, traci…
#    Compiling cpufeatures v0.2.17    ] 134/266: hyper, tracing-attributes, …
#    Compiling sync_wrapper v1.0.2    ] 135/266: cpufeatures, tracing-attrib…
#    Compiling rust_decimal v1.40.0   ] 136/266: sync_wrapper, tracing-attri…
#    Compiling ipnet v2.11.0          ] 137/266: sync_wrapper, tracing-attri…
#    Compiling unicode-xid v0.2.6     ] 138/266: tracing-attributes, url, ru…
#    Compiling crossbeam-utils v0.8.21] 139/266: unicode-xid, tracing-attrib…
#    Compiling base64 v0.22.1         ] 140/266: tracing-attributes, crossbe…
#    Compiling thiserror v1.0.69      ] 141/266: tracing-attributes, crossbe…
#    Compiling tower-layer v0.3.3     ] 142/266: thiserror(build.rs), tracin…
#    Compiling itertools v0.12.1      ] 144/266: thiserror(build.rs), tracin…
#    Compiling tower v0.5.3           ] 146/266: thiserror(build.rs), tracin…
#    Compiling derive_more-impl v2.1.1] 148/266: tower, thiserror(build.rs),…
#    Compiling sha1 v0.10.6           ] 149/266: thiserror(build.rs), tracin…
#    Compiling rand v0.9.2>           ] 152/266: anyhow, tracing-attributes,…
#    Compiling thiserror-impl v1.0.69 ] 153/266: anyhow, rand, tracing-attri…
#    Compiling tracing v0.1.44        ] 154/266: thiserror-impl, rand, traci…
#    Compiling hyper-util v0.1.19     ] 155/266: thiserror-impl, rand, rustl…
#    Compiling bitflags v2.10.0       ] 156/266: thiserror-impl, hyper-util,…
#    Compiling regex-syntax v0.8.8    ] 157/266: thiserror-impl, hyper-util,…
#    Compiling iana-time-zone v0.1.64 ] 158/266: thiserror-impl, hyper-util,…
#    Compiling data-encoding v2.10.0  ] 160/266: thiserror-impl, iana-time-z…
#    Compiling arrayvec v0.7.6        ] 161/266: thiserror-impl, iana-time-z…
#    Compiling utf-8 v0.7.6>          ] 162/266: thiserror-impl, iana-time-z…
#    Compiling iri-string v0.7.10     ] 163/266: thiserror-impl, regex-synta…
#    Compiling tungstenite v0.26.2    ] 164/266: thiserror-impl, iri-string,…
#    Compiling tower-http v0.6.8      ] 165/266: thiserror-impl, iri-string,…
#    Compiling chrono v0.4.43         ] 167/266: thiserror-impl, iri-string,…
#    Compiling regex-automata v0.4.13 ] 168/266: thiserror-impl, chrono, tun…
#    Compiling hyper-rustls v0.27.7   ] 169/266: thiserror-impl, regex-autom…
#    Compiling prost-derive v0.12.6   ] 170/266: thiserror-impl, regex-autom…
#    Compiling serde_urlencoded v0.7.1] 172/266: thiserror-impl, regex-autom…
#    Compiling webpki-roots v0.26.11  ] 173/266: thiserror-impl, regex-autom…
#    Compiling http-body-util v0.1.3  ] 174/266: thiserror-impl, regex-autom…
#    Compiling futures-executor v0.3.31 175/266: thiserror-impl, regex-autom…
#    Compiling tokio-util v0.7.18     ] 176/266: thiserror-impl, regex-autom…
#    Compiling pin-project-internal v1.1.10/266: thiserror-impl, regex-autom…
#    Compiling smol_str v0.3.5        ] 178/266: thiserror-impl, regex-autom…
#    Compiling syn v1.0.109=>         ] 179/266: thiserror-impl, regex-autom…
#    Compiling parking_lot_core v0.9.12 181/266: thiserror, regex-automata, …
#    Compiling derive_more v2.1.1     ] 182/266: parking_lot_core(build.rs),…
#    Compiling hashbrown v0.16.1      ] 183/266: parking_lot_core(build.rs),…
#    Compiling equivalent v1.0.2      ] 184/266: parking_lot_core(build.rs),…
#    Compiling barter-instrument v0.3.1 (/workspace/barter-instrument)roject…
#    Compiling serde_qs v0.13.0       ] 188/266: regex-automata, pin-project…
#    Compiling indexmap v2.13.0       ] 189/266: regex-automata, pin-project…
#    Compiling tokio-stream v0.1.18   ] 190/266: regex-automata, pin-project…
#    Compiling futures v0.3.31        ] 191/266: regex-automata, pin-project…
#    Compiling reqwest v0.12.28       ] 192/266: regex-automata, pin-project…
#    Compiling tokio-tungstenite v0.26.2193/266: reqwest, pin-project-intern…
#    Compiling crossbeam-epoch v0.9.18] 194/266: tokio-tungstenite, reqwest,…
#    Compiling hmac v0.12.1===>       ] 195/266: tokio-tungstenite, reqwest,…
#    Compiling itertools v0.14.0      ] 196/266: reqwest, pin-project-intern…
#    Compiling dirs-sys-next v0.1.2   ] 197/266: reqwest, pin-project-intern…
#    Compiling hex v0.4.3=====>       ] 198/266: dirs-sys-next, reqwest, pin…
#    Compiling lazy_static v1.5.0     ] 199/266: dirs-sys-next, reqwest, pin…
#    Compiling rayon-core v1.12.1     ] 200/266: dirs-sys-next, reqwest, pin…
#    Compiling scopeguard v1.2.0      ] 201/266: reqwest, pin-project-intern…
#    Compiling fnv v1.0.7=====>       ] 202/266: reqwest, pin-project-intern…
#    Compiling lock_api v0.4.14>      ] 203/266: reqwest, pin-project-intern…
#    Compiling dirs-next v2.0.0>      ] 204/266: reqwest, pin-project-intern…
#    Compiling crossbeam-deque v0.8.6 ] 205/266: dirs-next, reqwest, pin-pro…
#    Compiling convert_case v0.6.0    ] 208/266: parking_lot_core, reqwest, …
#    Compiling half v2.7.1=====>      ] 210/266: convert_case, reqwest, pin-…
#    Compiling is-terminal v0.4.17    ] 211/266: convert_case, reqwest, pin-…
#    Compiling csv-core v0.1.13>      ] 212/266: reqwest, pin-project-intern…
#    Compiling plotters-backend v0.3.7] 213/266: csv-core, reqwest, pin-proj…
#    Compiling anstyle v1.0.13==>     ] 214/266: csv-core, reqwest, pin-proj…
#    Compiling ciborium-io v0.2.2     ] 215/266: reqwest, pin-project-intern…
#    Compiling clap_lex v0.6.0==>     ] 216/266: reqwest, pin-project-intern…
#    Compiling ciborium-ll v0.2.2     ] 217/266: reqwest, pin-project-intern…
#    Compiling clap_builder v4.4.18   ] 218/266: reqwest, pin-project-intern…
#    Compiling barter-macro v0.2.0 (/workspace/barter-macro)n-project-intern…
#    Compiling plotters-svg v0.3.7    ] 220/266: barter-macro, reqwest, pin-…
#    Compiling csv v1.4.0=======>     ] 221/266: barter-macro, reqwest, pin-…
#    Compiling pin-project v1.1.10    ] 223/266: barter-macro, reqwest, pin-…
#    Compiling parking_lot v0.12.5    ] 224/266: barter-macro, reqwest, rayo…
#    Compiling term v0.7.0=======>    ] 225/266: barter-macro, reqwest, park…
#    Compiling sharded-slab v0.1.7    ] 226/266: barter-macro, reqwest, park…
#    Compiling prost v0.12.6=====>    ] 227/266: barter-macro, reqwest, pros…
#    Compiling barter-integration v0.9.2 (/workspace/barter-integration)pros…
#    Compiling matchers v0.2.0===>    ] 229/266: barter-macro, reqwest, bart…
#    Compiling tracing-log v0.2.0>    ] 230/266: barter-macro, reqwest, bart…
#    Compiling itertools v0.10.5=>    ] 231/266: barter-macro, reqwest, bart…
#    Compiling tracing-serde v0.2.0   ] 232/266: barter-macro, reqwest, bart…
#    Compiling async-trait v0.1.89    ] 233/266: barter-macro, reqwest, trac…
#    Compiling thread_local v1.1.9    ] 234/266: barter-macro, reqwest, trac…
#    Compiling unicode-width v0.1.14  ] 235/266: barter-macro, reqwest, iter…
#    Compiling nu-ansi-term v0.50.3   ] 236/266: barter-macro, reqwest, unic…
#    Compiling encode_unicode v1.0.0  ] 237/266: barter-macro, reqwest, unic…
#    Compiling vecmap-rs v0.2.4===>   ] 238/266: barter-macro, encode_unicod…
#    Compiling same-file v1.0.6===>   ] 239/266: barter-macro, encode_unicod…
#    Compiling cast v0.3.0========>   ] 240/266: barter-macro, encode_unicod…
#    Compiling walkdir v2.5.0=====>   ] 241/266: barter-macro, encode_unicod…
#    Compiling prettytable-rs v0.10.0 ] 242/266: barter-macro, encode_unicod…
#    Compiling criterion-plot v0.5.0  ] 243/266: barter-macro, encode_unicod…
#    Compiling tracing-subscriber v0.3.2244/266: barter-macro, encode_unicod…
#    Compiling barter-execution v0.6.0 (/workspace/barter-execution)ytable-r…
#    Compiling rayon v1.10.0=======>  ] 246/266: prettytable-rs, walkdir, cr…
#    Compiling clap v4.4.18========>  ] 247/266: rayon, prettytable-rs, crit…
#    Compiling plotters v0.3.7=====>  ] 248/266: rayon, prettytable-rs, clap…
#    Compiling ciborium v0.2.2=====>  ] 249/266: rayon, plotters, prettytabl…
#    Compiling regex v1.12.2=======>  ] 250/266: rayon, plotters, ciborium, …
#    Compiling tinytemplate v1.2.1=>  ] 251/266: rayon, plotters, regex, tra…
#    Compiling oorandom v11.1.5====>  ] 252/266: rayon, tinytemplate, regex,…
#    Compiling anes v0.1.6=========>  ] 253/266: oorandom, tinytemplate, reg…
#    Compiling criterion v0.5.1====>  ] 254/266: tinytemplate, anes, regex, …
#    Compiling rust_decimal_macros v1.40.05/266: criterion, tinytemplate, re…
#    Compiling spin_sleep v1.3.3====> ] 256/266: criterion, tinytemplate, ru…
#    Compiling barter-data v0.10.2 (/workspace/barter-data) rust_decimal_mac…
# warning: extern crate `prost` is unused in crate `barter_data`_mac…
#   |
#   = help: remove the dependency or add `use prost as _;` to the crate root
# note: the lint level is defined here
#  --> barter-data/src/lib.rs:5:5
#   |
# 5 |     unused_crate_dependencies,
#   |     ^^^^^^^^^^^^^^^^^^^^^^^^^
#
#    Compiling barter v0.12.3 (/workspace/barter)barter-data
# warning: type does not implement `Debug`; consider adding `#[derive(Debug)]` or a manual implementation
#   --> barter/src/logging.rs:36:1
#    |
# 36 | pub struct AuditSpanFilter;
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#    |
# note: the lint level is defined here
#   --> barter/src/lib.rs:9:5
#    |
#  9 |     missing_debug_implementations,
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: `barter` (lib) generated 1 warning66: barter, barter-data
# warning: `barter-data` (lib) generated 1 warningarter-data
#     Finished `release` profile [optimized] target(s) in 1m 43sals_backtest…
#      Running `target/release/examples/bond_event_signals_backtest /workspace/data/bond_marks_template.csv /workspace/data/bond_signals_template.csv`
# Using provided paths:
#   Marks: /workspace/data/bond_marks_template.csv
#   Signals: /workspace/data/bond_signals_template.csv
#
#  BOND EVENT BACKTEST SUMMARY
# ┌──────────────────────────┬──────────┐
# │ Metric                   │ Value    │
# ├──────────────────────────┼──────────┤
# │ Total Return             │ -0.0217% │
# ├──────────────────────────┼──────────┤
# │ Annualized Return (CAGR) │ -0.0216% │
# ├──────────────────────────┼──────────┤
# │ Max Drawdown             │ -0.1124% │
# ├──────────────────────────┼──────────┤
# │ Annualized Volatility    │ 0.0828%  │
# ├──────────────────────────┼──────────┤
# │ Sharpe Ratio (Ann.)      │ -0.2621  │
# ├──────────────────────────┼──────────┤
# │ Trading Days             │ 366      │
# └──────────────────────────┴──────────┘
#
# First 5 points:
#   2025-01-01 nav=1.000000 dd=0.000000
#   2025-01-02 nav=0.999977 dd=-0.000022
#   2025-01-03 nav=0.999950 dd=-0.000049
#   2025-01-04 nav=0.999930 dd=-0.000069
#   2025-01-05 nav=0.999927 dd=-0.000072
#
# Last 5 points:
#   2025-12-28 nav=0.999782 dd=-0.000217
#   2025-12-29 nav=0.999782 dd=-0.000217
#   2025-12-30 nav=0.999782 dd=-0.000217
#   2025-12-31 nav=0.999782 dd=-0.000217
#   2026-01-01 nav=0.999782 dd=-0.000217
# CPU times: user 2.05 s, sys: 465 ms, total: 2.52 s
# Wall time: 1min 53s

# %%
# !pwd
# Out:
# /workspace
