# %%
# %%time
# !cargo run --release -p barter --example bond_event_signals_backtest -- /workspace/data/bond_marks_template.csv /workspace/data/bond_signals_template.csv
# Out:
# warning: extern crate `prost` is unused in crate `barter_data`
#   |
#   = help: remove the dependency or add `use prost as _;` to the crate root
# note: the lint level is defined here
#  --> barter-data/src/lib.rs:5:5
#   |
# 5 |     unused_crate_dependencies,
#   |     ^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: `barter-data` (lib) generated 1 warning
# warning: type does not implement `Debug`; consider adding `#[derive(Debug)]` or a manual implementation
#   --> barter/src/logging.rs:36:1
#    |
# 36 | pub struct AuditSpanFilter;
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#    |
# note: the lint level is defined here
#   --> barter/src/lib.rs:9:5
#    |
#  9 |     missing_debug_implementations,
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: `barter` (lib) generated 1 warning
# warning: unused import: `FromPrimitive`
#  --> barter/examples/bond_event_signals_backtest.rs:4:29
#   |
# 4 | use rust_decimal::prelude::{FromPrimitive, ToPrimitive};
#   |                             ^^^^^^^^^^^^^
#   |
#   = note: `#[warn(unused_imports)]` (part of `#[warn(unused)]`) on by default
#
# warning: field `pnl` is never read
#    --> barter/examples/bond_event_signals_backtest.rs:158:5
#     |
# 155 | struct EquityPoint {
#     |        ----------- field in this struct
# ...
# 158 |     pnl: Decimal,
#     |     ^^^
#     |
#     = note: `EquityPoint` has derived impls for the traits `Clone` and `Debug`, but these are intentionally ignored during dead code analysis
#     = note: `#[warn(dead_code)]` (part of `#[warn(unused)]`) on by default
#
# warning: field `daily_sharpe` is never read
#    --> barter/examples/bond_event_signals_backtest.rs:431:5
#     |
# 427 | struct BacktestStats {
#     |        ------------- field in this struct
# ...
# 431 |     daily_sharpe: Decimal,
#     |     ^^^^^^^^^^^^
#     |
#     = note: `BacktestStats` has derived impls for the traits `Clone` and `Debug`, but these are intentionally ignored during dead code analysis
#
# warning: `barter` (example "bond_event_signals_backtest") generated 3 warnings (run `cargo fix --example "bond_event_signals_backtest" -p barter` to apply 1 suggestion)
#     Finished `release` profile [optimized] target(s) in 0.18s
#      Running `target/release/examples/bond_event_signals_backtest /workspace/data/bond_marks_template.csv /workspace/data/bond_signals_template.csv`
# Using provided paths:
#   Marks: /workspace/data/bond_marks_template.csv
#   Signals: /workspace/data/bond_signals_template.csv
#
#  BOND EVENT BACKTEST SUMMARY
# ┌──────────────────────────┬──────────┐
# │ Metric                   │ Value    │
# ├──────────────────────────┼──────────┤
# │ Total Return             │ 0.0236%  │
# ├──────────────────────────┼──────────┤
# │ Annualized Return (CAGR) │ 0.0235%  │
# ├──────────────────────────┼──────────┤
# │ Max Drawdown             │ -0.0110% │
# ├──────────────────────────┼──────────┤
# │ Annualized Volatility    │ 0.0354%  │
# ├──────────────────────────┼──────────┤
# │ Sharpe Ratio (Ann.)      │ 0.6654   │
# ├──────────────────────────┼──────────┤
# │ Trading Days             │ 366      │
# └──────────────────────────┴──────────┘
#
# First 5 points:
#   2025-01-01 nav=1.000000 dd=0.000000
#   2025-01-02 nav=1.000000 dd=0.000000
#   2025-01-03 nav=1.000000 dd=0.000000
#   2025-01-04 nav=1.000000 dd=0.000000
#   2025-01-05 nav=1.000000 dd=0.000000
#
# Last 5 points:
#   2025-12-28 nav=1.000236 dd=-0.000099
#   2025-12-29 nav=1.000236 dd=-0.000099
#   2025-12-30 nav=1.000236 dd=-0.000099
#   2025-12-31 nav=1.000236 dd=-0.000099
#   2026-01-01 nav=1.000236 dd=-0.000099
# CPU times: user 10.8 ms, sys: 13.3 ms, total: 24.1 ms
# Wall time: 406 ms

# %%
# !pwd
# Out:
# /workspace
